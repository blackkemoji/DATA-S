# %%
import pandas as pd

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\Erick Mwangi\Documents\GOLD MEDAL.csv')

# %%
df.head()
# Out:
#    COUNTRY  GOLD MEDAL
# 0      USA          46
# 1       GB          27
# 2   RUSSIA          19
# 3   CHINA           26
# 4  GERMANY          17

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv(r'C:\Users\Erick Mwangi\Documents\GOLD MEDAL.csv')
country = df["COUNTRY"]
medal= df["GOLD MEDAL"]
plt.bar(country, medal, label="AWARD", color='g')
plt.plot()
plt.xlabel("country")
plt.ylabel("medal")
plt.title("Gold medal achievements of five most successful\n"+"countries in 2023 SummerOlympics")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv(r'C:\Users\Erick Mwangi\Documents\GOLD MEDAL.csv')
country = df["COUNTRY"]
medal= df["GOLD MEDAL"]
plt.plot(country, medal, label="Distribution",color='g')
plt.plot()
plt.xlabel("country")
plt.ylabel("medal")
plt.title("Gold medal achievements of five most successful\n"+"countries in 2023 SummerOlympics")
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv(r'C:\Users\Erick Mwangi\Documents\GOLD MEDAL.csv')
country = df["COUNTRY"]
medal = df["GOLD MEDAL"]
explode = (0.1, 0, 0, 0, 0)
colour=['g','r','b','y','w']
plt.pie(medal, labels=country_data, explode=explode, colors=colour,autopct='%1.1f%%', shadow=True, startangle=140)
plt.title("Gold medal achievements of five most successful\n"+"countries in 2023 SummerOlympics")
plt.show()
